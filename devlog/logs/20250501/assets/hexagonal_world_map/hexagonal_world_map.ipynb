# %%
import pandas as pd
import geopandas as gpd
import geodatasets
import h3pandas
import rasterstats
import matplotlib.pyplot as plt
import rasterio
from rasterio.vrt import WarpedVRT
from rasterio import transform
from rasterio.plot import show
import rioxarray
import xarray
import tszip
import numpy as np
import sys
sys.path.append("/Users/jameskitchens/Documents/GitHub/terracotta")
import terracotta as tct
import importlib
importlib.reload(tct)
# Out:
# <module 'terracotta' from '/Users/jameskitchens/Documents/GitHub/terracotta/terracotta/__init__.py'>

# %%
gdf = gpd.read_file(geodatasets.get_url("naturalearth land"))
gdf = gdf.loc[112:112]
resolution = 2
gdf_h3 = gdf.h3.polyfill_resample(resolution)
gdf_h3 = gdf_h3.reset_index()
gdf_h3["deme"] = gdf_h3.index

#gdf_h3.plot()
#plt.axis("off")
#plt.savefig("images/antimeridian_error.png")
#plt.show()

gdf_h3.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_d9f7dcf0ccb6adffbc72a57144d6755d {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_d9f7dcf0ccb6adffbc72a57144d6755d&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_d9f7dcf0ccb6adffbc72a57144d6755d = L.map(
#                 &quot;map_d9f7dcf0ccb6adffbc72a57144d6755d&quot;,
#                 {
#                     center: [21.741085218722674, -0.17007669245582235],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_d9f7dcf0ccb6adffbc72a57144d6755d);
#
#
#
#
#
#             var tile_layer_e302313d3b1afaff88d6386f8a765c96 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e302313d3b1afaff88d6386f8a765c96.addTo(map_d9f7dcf0ccb6adffbc72a57144d6755d);
#
#
#             map_d9f7dcf0ccb6adffbc72a57144d6755d.fitBounds(
#                 [[-34.8532465436253, -179.90258617233593], [78.33541698107065, 179.56243278742429]],
#                 {}
#             );
#
#
#         function geo_json_0e675a58a7325c2a0b81fa9760e11e1f_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_0e675a58a7325c2a0b81fa9760e11e1f_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_0e675a58a7325c2a0b81fa9760e11e1f_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_0e675a58a7325c2a0b81fa9760e11e1f_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_0e675a58a7325c2a0b81fa9760e11e1f_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_0e675a58a7325c2a0b81fa9760e11e1f.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_0e675a58a7325c2a0b81fa9760e11e1f_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_0e675a58a7325c2a0b81fa9760e11e1f = L.geoJson(null, {
#                 onEachFeature: geo_json_0e675a58a7325c2a0b81fa9760e11e1f_onEachFeature,
#
#                 style: geo_json_0e675a58a7325c2a0b81fa9760e11e1f_styler,
#                 pointToLayer: geo_json_0e675a58a7325c2a0b81fa9760e11e1f_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_0e675a58a7325c2a0b81fa9760e11e1f_add (data) {
#             geo_json_0e675a58a7325c2a0b81fa9760e11e1f
#                 .addData(data);
#         }
#             geo_json_0e675a58a7325c2a0b81fa9760e11e1f_add({&quot;bbox&quot;: [-179.90258617233593, -34.8532465436253, 179.56243278742429, 78.33541698107065], &quot;features&quot;: [{&quot;bbox&quot;: [46.9686209628495, 17.797749012021796, 50.16499778196583, 20.59809474557387], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[47.867839878662906, 20.59809474557387], [46.9686209628495, 19.179955228717326], [47.6958087502292, 17.797749012021796], [49.27506948076003, 17.82666678465199], [50.16499778196583, 19.206256304953666], [49.48574871263946, 20.594835079567716], [47.867839878662906, 20.59809474557387]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;deme&quot;: 0, &quot;featurecla&quot;: &quot

# %%
gdf_h3 = gdf_h3.drop([606, 777, 78, 62, 805, 497, 811, 428]) #drop these because of antimeridian

#gdf_h3.plot()
#plt.axis("off")
#plt.savefig("images/antimeridian_solution.png")
#plt.show()

gdf_h3.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_5c8800c762727c5c3e8b814dc49aed91 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_5c8800c762727c5c3e8b814dc49aed91&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_5c8800c762727c5c3e8b814dc49aed91 = L.map(
#                 &quot;map_5c8800c762727c5c3e8b814dc49aed91&quot;,
#                 {
#                     center: [21.741085218722674, 78.5961668322459],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_5c8800c762727c5c3e8b814dc49aed91);
#
#
#
#
#
#             var tile_layer_0fa8032d6489ee28423a69cda16512af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_0fa8032d6489ee28423a69cda16512af.addTo(map_5c8800c762727c5c3e8b814dc49aed91);
#
#
#             map_5c8800c762727c5c3e8b814dc49aed91.fitBounds(
#                 [[-34.8532465436253, -18.022267576148227], [78.33541698107065, 175.21460124064004]],
#                 {}
#             );
#
#
#         function geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf = L.geoJson(null, {
#                 onEachFeature: geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_onEachFeature,
#
#                 style: geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_styler,
#                 pointToLayer: geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_add (data) {
#             geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf
#                 .addData(data);
#         }
#             geo_json_5bbbfb3f6df2f05c8c415800a2bab7cf_add({&quot;bbox&quot;: [-18.022267576148227, -34.8532465436253, 175.21460124064004, 78.33541698107065], &quot;features&quot;: [{&quot;bbox&quot;: [46.9686209628495, 17.797749012021796, 50.16499778196583, 20.59809474557387], &quot;geometry&quot;: {&quot;coordinates&quot;: [[[47.867839878662906, 20.59809474557387], [46.9686209628495, 19.179955228717326], [47.6958087502292, 17.797749012021796], [49.27506948076003, 17.82666678465199], [50.16499778196583, 19.206256304953666], [49.48574871263946, 20.594835079567716], [47.867839878662906, 20.59809474557387]]], &quot;type&quot;: &quot;Polygon&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;deme&quot;: 0, &quot;featurecla&quot;: &quot;Lan

# %%
xds = xarray.open_dataset("ETOPO2v2c_f4.nc")
xds["z"].rio.to_raster("world_elevation.tif")

with rasterio.open("world_elevation.tif") as src_dst:
    with WarpedVRT(
        src_dst,
        src_crs=src_dst.gcps[1],
        src_transform=transform.from_gcps(src_dst.gcps[0]),
    ) as vrt:
        mean_elev = []
        for stat in rasterstats.zonal_stats(
            gdf_h3,
            vrt.read(1),
            affine=vrt.transform,
            stats="mean"
        ):
            mean_elev.append(stat["mean"])
        gdf_h3["mean_elev"] = mean_elev

gdf_h3.plot(column="mean_elev")
plt.axis("off")
plt.savefig("images/elevation_by_deme.png")
plt.show()
# Out:
# /opt/anaconda3/envs/terracotta/lib/python3.12/site-packages/rasterstats/io.py:335: NodataWarning: Setting nodata to -999; specify nodata explicitly
#   warnings.warn(

# %%
gdf_h3["mean_elev"].plot.hist()
plt.savefig("images/histogram_of_mean_elevations.png")
plt.show()

# %%
bins = [-10000, 3000, 8000]
gdf_h3["binned_elev"] = np.searchsorted(bins, gdf_h3["mean_elev"].values)

# %%
gdf_h3.plot(column="binned_elev")
plt.axis("off")
#plt.savefig("images/binned_elevation_by_deme.png")
plt.show()

# %%
sample_locs = pd.read_csv("sample_locations.csv")
sample_locs = gpd.GeoDataFrame(sample_locs, geometry=gpd.GeoSeries.from_xy(sample_locs["lon"], sample_locs["lat"]), crs=4326)
sample_locs.explore()
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_33213b092657b51b9215c138f075bf56 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#
#                     &lt;style&gt;
#                         .foliumtooltip {
#
#                         }
#                        .foliumtooltip table{
#                             margin: auto;
#                         }
#                         .foliumtooltip tr{
#                             text-align: left;
#                         }
#                         .foliumtooltip th{
#                             padding: 2px; padding-right: 8px;
#                         }
#                     &lt;/style&gt;
#
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_33213b092657b51b9215c138f075bf56&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_33213b092657b51b9215c138f075bf56 = L.map(
#                 &quot;map_33213b092657b51b9215c138f075bf56&quot;,
#                 {
#                     center: [14.300000000000004, 8.349999999999994],
#                     crs: L.CRS.EPSG3857,
#                     ...{
#   &quot;zoom&quot;: 10,
#   &quot;zoomControl&quot;: true,
#   &quot;preferCanvas&quot;: false,
# }
#
#                 }
#             );
#             L.control.scale().addTo(map_33213b092657b51b9215c138f075bf56);
#
#
#
#
#
#             var tile_layer_e55942617fbe47741700408d0339f7bd = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {
#   &quot;minZoom&quot;: 0,
#   &quot;maxZoom&quot;: 19,
#   &quot;maxNativeZoom&quot;: 19,
#   &quot;noWrap&quot;: false,
#   &quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;,
#   &quot;subdomains&quot;: &quot;abc&quot;,
#   &quot;detectRetina&quot;: false,
#   &quot;tms&quot;: false,
#   &quot;opacity&quot;: 1,
# }
#
#             );
#
#
#             tile_layer_e55942617fbe47741700408d0339f7bd.addTo(map_33213b092657b51b9215c138f075bf56);
#
#
#             map_33213b092657b51b9215c138f075bf56.fitBounds(
#                 [[-41.3, -157.8], [69.9, 174.5]],
#                 {}
#             );
#
#
#         function geo_json_11c806199a9f9a994634ed09248b2c4e_styler(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.5, &quot;weight&quot;: 2};
#             }
#         }
#         function geo_json_11c806199a9f9a994634ed09248b2c4e_highlighter(feature) {
#             switch(feature.id) {
#                 default:
#                     return {&quot;fillOpacity&quot;: 0.75};
#             }
#         }
#         function geo_json_11c806199a9f9a994634ed09248b2c4e_pointToLayer(feature, latlng) {
#             var opts = {&quot;bubblingMouseEvents&quot;: true, &quot;color&quot;: &quot;#3388ff&quot;, &quot;dashArray&quot;: null, &quot;dashOffset&quot;: null, &quot;fill&quot;: true, &quot;fillColor&quot;: &quot;#3388ff&quot;, &quot;fillOpacity&quot;: 0.2, &quot;fillRule&quot;: &quot;evenodd&quot;, &quot;lineCap&quot;: &quot;round&quot;, &quot;lineJoin&quot;: &quot;round&quot;, &quot;opacity&quot;: 1.0, &quot;radius&quot;: 2, &quot;stroke&quot;: true, &quot;weight&quot;: 3};
#
#             let style = geo_json_11c806199a9f9a994634ed09248b2c4e_styler(feature)
#             Object.assign(opts, style)
#
#             return new L.CircleMarker(latlng, opts)
#         }
#
#         function geo_json_11c806199a9f9a994634ed09248b2c4e_onEachFeature(feature, layer) {
#             layer.on({
#                 mouseout: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                             geo_json_11c806199a9f9a994634ed09248b2c4e.resetStyle(e.target);
#                     }
#                 },
#                 mouseover: function(e) {
#                     if(typeof e.target.setStyle === &quot;function&quot;){
#                         const highlightStyle = geo_json_11c806199a9f9a994634ed09248b2c4e_highlighter(e.target.feature)
#                         e.target.setStyle(highlightStyle);
#                     }
#                 },
#             });
#         };
#         var geo_json_11c806199a9f9a994634ed09248b2c4e = L.geoJson(null, {
#                 onEachFeature: geo_json_11c806199a9f9a994634ed09248b2c4e_onEachFeature,
#
#                 style: geo_json_11c806199a9f9a994634ed09248b2c4e_styler,
#                 pointToLayer: geo_json_11c806199a9f9a994634ed09248b2c4e_pointToLayer,
#             ...{
# }
#         });
#
#         function geo_json_11c806199a9f9a994634ed09248b2c4e_add (data) {
#             geo_json_11c806199a9f9a994634ed09248b2c4e
#                 .addData(data);
#         }
#             geo_json_11c806199a9f9a994634ed09248b2c4e_add({&quot;bbox&quot;: [-157.8, -41.3, 174.5, 69.9], &quot;features&quot;: [{&quot;bbox&quot;: [-12.0, 12.0, -12.0, 12.0], &quot;geometry&quot;: {&quot;coordinates&quot;: [-12.0, 12.0], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;0&quot;, &quot;properties&quot;: {&quot;id&quot;: 0, &quot;lat&quot;: 12.0, &quot;lon&quot;: -12.0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [-12.0, 12.0, -12.0, 12.0], &quot;geometry&quot;: {&quot;coordinates&quot;: [-12.0, 12.0], &quot;type&quot;: &quot;Point&quot;}, &quot;id&quot;: &quot;1&quot;, &quot;properties&quot;: {&quot;id&quot;: 1, &quot;lat&quot;: 12.0, &quot;lon&quot;: -12.0}, &quot;type&quot;: &quot;Feature&quot;}, {&quot;bbox&quot;: [17.0, 4.0, 17.0, 4.0], &quot;geometry&quot

# %%
sample_locs_with_region = gpd.sjoin(sample_locs, gdf_h3, how="inner", predicate="within").loc[:, ["id", "deme"]]
#sample_locs_with_region = sample_locs_with_region.drop_duplicates("deme")
regions_with_samples = sample_locs_with_region["deme"].unique()

# %%
gdf_h3["geometry"] = gdf_h3.buffer(0.1)
with open("demes_elev_two_type.tsv", "w") as outfile:
    outfile.write("id\txcoord\tycoord\ttype\tneighbours\n")
    for i, row in gdf_h3.iterrows():
        neighbors = np.array(gdf_h3[gdf_h3.geometry.touches(row['geometry'])].deme)
        #overlapping neighbors use if discrepances found with touches
        overlap = np.array(gdf_h3[gdf_h3.geometry.overlaps(row['geometry'])].deme)
        neighbors = [str(d) for d in np.sort(np.union1d(neighbors, overlap))]
        center = row["geometry"].centroid
        outfile.write(f"{row["deme"]}\t{center.x}\t{center.y}\t{row["binned_elev"]-1}\t{",".join(neighbors)}\n")
# Out:
# /var/folders/q8/b10jdgls4xvcv3wz767kf6f80000gn/T/ipykernel_1809/1284224074.py:1: UserWarning: Geometry is in a geographic CRS. Results from 'buffer' are likely incorrect. Use 'GeoSeries.to_crs()' to re-project geometries to a projected CRS before this operation.
#
#   gdf_h3["geometry"] = gdf_h3.buffer(0.1)

# %%
ts = tszip.load("hgdp_tgp_sgdp_high_cov_ancients_chr17_p.dated.trees.tsz")
ts, map_nodes = ts.simplify(samples=sample_locs_with_region["id"], map_nodes=True)
sample_locs_with_region["orig_id"] = sample_locs_with_region["id"]
sample_locs_with_region["id"] = map_nodes[sample_locs_with_region["id"]]
sample_locs_with_region.to_csv("samples_two_type.tsv", sep="\t", index=False)

# %%
demes = pd.read_csv("demes.tsv", sep="\t")
samples = pd.read_csv("samples.tsv", sep="\t")
world_map = tct.WorldMap(demes, samples)

# %%
world_map.draw(figsize=(20,20), show_samples=True, save_to="images/terracotta_world_map.png")

# %%
connections = []
deme_types = range(world_map.demes["type"].max()+1)
for i,type0 in enumerate(deme_types):
    for type1 in deme_types[i:]:
        connections.append(f"{type0}-{type1}")
counts = world_map.connections["type"].value_counts().sort_index()
pd.DataFrame(connections, columns=["connection"]).join(counts)
# Out:
#    connection  count
# 0         0-0   1014
# 1         0-1     71
# 2         0-2      9
# 3         0-3    385
# 4         0-4      7
# 5         1-1    261
# 6         1-2     43
# 7         1-3    222
# 8         1-4     20
# 9         2-2      6
# 10        2-3     10
# 11        2-4     22
# 12        3-3    262
# 13        3-4      5
# 14        4-4     75

# %%
from os import mkdir

def create_trees_folder_from_ts(ts, output_path=".", gap_between_trees=1, discretize_time=False):
    mkdir(f"{output_path}/trees")
    for i in range(0, ts.num_trees, gap_between_trees):
        tree = ts.at_index(i)
        interval = tree.interval
        single_tree_ts = ts.keep_intervals([interval], simplify=True).trim()
        single_tree_ts.dump(f"{output_path}/trees/{i}.trees")
        #if discretize_time != False:
        #    discretized_ts = tct.nx_bin_ts(single_tree_ts, discretize_time)
        #    discretized_ts.dump(f"{output_path}/trees/{i}.trees")
        #else:
        #    single_tree_ts.dump(f"{output_path}/trees/{i}.trees")

create_trees_folder_from_ts(
    ts=ts,
    gap_between_trees=1000
)

# %%
import tskit
print(tskit.load("trees/0.trees").draw_text())
# Out:
# 100000.00┊                                                                                                                     90                                                                                                          ┊
#          ┊             ┏━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━┻━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━━━━━┳━━━━━┳━━━┳━━━┳━━━━━━━━━━┳━━━━━━━━┳━━┳━━┓ ┊
# 10000.00 ┊            87                           88                ┃                                    83                                      ┃                     84                       ┃    89   ┃  86         85        ┃  ┃  ┃ ┊
#          ┊ ┏━━┳━━┳━━┳━━╋━━┳━━┳━━┳━━┓ ┏━━┳━━┳━━┳━━┳━━╋━━┳━━┳━━┳━━┳━━┓ ┃ ┏━┳━┳━━┳━━━━┳━━━┳━━┳━━━━━┳━━━━━┳━━┳━┻━┳━━━━┳━━┳━━┳━━┳━━┳━━┳━━┳━━┳━━┳━━┳━━┓ ┃ ┏━━┳━━━━┳━━┳━━┳━━┳━━┳┻━┳━━┳━━┳━━┳━━┳━━┳━━┓   ┃   ┏━┻┓  ┃  ┏┻━┓  ┏━━┳━━╋━━┳━━┓  ┃  ┃  ┃ ┊
# 1000.00  ┊ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┃ ┃  ┃   81   ┃  ┃    79     ┃  ┃  80    ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ 82    ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃   ┃   ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┊
#          ┊ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┃ ┃  ┃  ┏━┻┓  ┃  ┃  ┏━━╋━━┓  ┃  ┃  ┏┻━┓  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┏┻━┓  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃   ┃   ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┊
# 100.00   ┊ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  78   ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┊
#          ┊ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┃ ┃ ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┏━┻┓  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃  ┃ ┊
# 0.00     ┊ 0 10 16 18 21 47 56 71 77 1 15 33 37 42 49 57 61 63 64 69 2 3 6 8 11 19 32 24 25 31 45 50 34 35 36 72 38 48 51 53 55 59 60 65 70 74 75 4 5 9 22 12 14 17 23 29 30 40 41 46 58 66 68 7 44 13 52 20 26 27 28 43 54 62 67 39 73 76 ┊
#          0                                                                                                                                                                                                                              282304
